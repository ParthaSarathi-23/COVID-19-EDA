# %% [markdown]
# # Importing Library

# %%
import random
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# # Date-Wise

# %%
df = pd.read_csv("/content/drive/MyDrive/Covid_19/day_wise.csv")

# %%
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
rowColumn = df.shape
print("No of Rows   : ",rowColumn[0])
print("No of Column : ",rowColumn[1])
print("Size         : ",df.size)
# Out:
# No of Rows   :  188
# No of Column :  12
# Size         :  2256

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
df.isnull()
# Out:
#       Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    False      False   False      False   False      False       False
# 1    False      False   False      False   False      False       False
# 2    False      False   False      False   False      False       False
# 3    False      False   False      False   False      False       False
# 4    False      False   False      False   False      False       False
# ..     ...        ...     ...        ...     ...        ...         ...
# 183  False      False   False      False   False      False       False
# 184  False      False   False      False   False      False       False
# 185  False      False   False      False   False      False       False
# 186  False      False   False      False   False      False       False
# 187  False      False   False      False   False      False       False
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
Death_Ratio = list(df[columns[8]])

print("Maximum Death Ratio Date")
print("------------------------")
print("Date        : ",df.iloc[Death_Ratio.index(max(Death_Ratio))][columns[0]])
print("Death Ratio : ",max(Death_Ratio))
# Out:
# Maximum Death Ratio Date
# ------------------------
# Date        :  2020-04-24
# Death Ratio :  7.18

# %%
Recovered_Ratio = list(df[columns[9]])

print("Maximum Recovered Ratio Date")
print("----------------------------")
print("Date            : ",df.iloc[Recovered_Ratio.index(max(Recovered_Ratio))][columns[0]])
print("Recovered Ratio : ",max(Recovered_Ratio))
# Out:
# Maximum Recovered Ratio Date
# ----------------------------
# Date            :  2020-07-27
# Recovered Ratio :  57.45

# %%
Active_Ratio = []

for i in range(0, len(df)):
  Active_Ratio.append((df.iloc[i]['Active']/df.iloc[i]['Confirmed'])*100)

print("Maximum Death Ratio Date")
print("------------------------")
print("Date        : ",df.iloc[Active_Ratio.index(max(Active_Ratio))][columns[0]])
print("Death Ratio : ",round(max(Active_Ratio), 2))
# Out:
# Maximum Death Ratio Date
# ------------------------
# Date        :  2020-01-30
# Death Ratio :  96.21

# %%
Country = list(df[columns[len(columns)-1]])


print("Maximum No of Country")
print("---------------------")
print("Date          : ", df.iloc[Country.index(max(Country))][columns[0]])
print("No of Country : ", max(Country))
# Out:
# Maximum No of Country
# ---------------------
# Date          :  2020-05-13
# No of Country :  187

# %%
Confirmed = []
Death = []
Recovered = []
Active = []
Date = []
for i in range(0, len(df), 25):
  Date.append(df.iloc[i]['Date'])
  Confirmed.append(df.iloc[i]['Confirmed'])
  Death.append(df.iloc[i]['Deaths'])
  Recovered.append(df.iloc[i]['Recovered'])
  Active.append(df.iloc[i]['Active'])

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=Date, y=Confirmed, name='Confirmed'))
fig.add_trace(go.Bar(x=Date, y=Death, name='Deaths'))

fig.update_layout(
    xaxis=dict(title='Date'),
    yaxis=dict(title='Number of Cases'),
    title='Confirmed VS Deaths',
    barmode='group',  # 'group' for grouped bars, 'stack' for stacked bars
    width=800,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='Date', y='Deaths / 100 Cases', title='Deaths / 100 Cases Over Time')
fig.update_layout(xaxis_title='Date', yaxis_title='Deaths / 100 Cases', width=800, height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=Date, y=Confirmed, name='Confirmed'))
fig.add_trace(go.Bar(x=Date, y=Recovered, name='Recovered'))

fig.update_layout(
    xaxis=dict(title='Date'),
    yaxis=dict(title='Number of Cases'),
    title='Confirmed VS Recovered',
    barmode='group',  # 'group' for grouped bars, 'stack' for stacked bars
    width=800,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='Date', y='Recovered / 100 Cases', title='Recovered / 100 Cases Over Time')
fig.update_layout(xaxis_title='Date', yaxis_title='Recovered / 100 Cases', width=800, height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=Date, y=Confirmed, name='Confirmed'))
fig.add_trace(go.Bar(x=Date, y=Active, name='Active'))

fig.update_layout(
    xaxis=dict(title='Date'),
    yaxis=dict(title='Number of Cases'),
    title='Confirmed VS Active',
    barmode='group',  # 'group' for grouped bars, 'stack' for stacked bars
    width=800,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='Date', y=Active_Ratio, title='Active / 100 Cases Over Time')
fig.update_layout(xaxis_title='Date', yaxis_title='Active / 100 Cases', width=800, height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='Date', y='No. of countries', title='Covid VS No.of.Country')
fig.update_layout(xaxis_title='Date', yaxis_title='Number of Countries', width=800, height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Country-Wise

# %%
df = pd.read_csv("/content/drive/MyDrive/Covid_19/country_wise_latest.csv")

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
rowColumn = df.shape
print("No of Rows   : ",rowColumn[0])
print("No of Column : ",rowColumn[1])
print("Size         : ",df.size)
# Out:
# No of Rows   :  187
# No of Column :  15
# Size         :  2805

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.nlargest(5, ['Confirmed'])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
# 23          Brazil    2442375   87618    1846641   508116      23284
# 79           India    1480073   33408     951166   495499      44457
# 138         Russia     816680   13334     602249   201097       5607
# 154   South Africa     452529    7067     274925   170537       7096
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 79          637          33598                2.26                  64.26
# 138          85           3077                1.63                  73.74
# 154         298           9848                1.56                  60.75
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.nlargest(5, ['Active'])
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 177  United Kingdom     301708   45844       1437   254427        688
# 138          Russia     816680   13334     602249   201097       5607
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 79          637          33598                2.26                  64.26
# 177           7              3               15.19                   0.48
# 138          85           3077                1.63                  73.74
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.nlargest(5, ['Deaths'])
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 177           7              3               15.19                   0.48
# 111         342           8588               11.13                  76.82
# 85            5            147               14.26                  80.64
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.nlargest(5, ['Recovered'])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 23          Brazil    2442375   87618    1846641   508116      23284
# 173             US    4290259  148011    1325804  2816444      56336
# 79           India    1480073   33408     951166   495499      44457
# 138         Russia     816680   13334     602249   201097       5607
# 35           Chile     347923    9187     319954    18782       2133
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23          614          33728                3.59                  75.61
# 173        1076          27941                3.45                  30.90
# 79          637          33598                2.26                  64.26
# 138          85           3077                1.63                  73.74
# 35           75           1859                2.64                  91.96
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
coordinates ={
    'Afghanistan': {'latitude': 33.9391, 'longitude': 67.7100},
    'Albania': {'latitude': 41.1533, 'longitude': 20.1683},
    'Algeria': {'latitude': 28.0339, 'longitude': 1.6596},
    'Andorra': {'latitude': 42.5063, 'longitude': 1.5218},
    'Angola': {'latitude': -11.2027, 'longitude': 17.8739},
    'Antigua and Barbuda': {'latitude': 17.0608, 'longitude': -61.7964},
    'Argentina': {'latitude': -38.4192, 'longitude': -63.5980},
    'Armenia': {'latitude': 40.0691, 'longitude': 45.0382},
    'Australia': {'latitude': -25.2744, 'longitude': 133.7751},
    'Austria': {'latitude': 47.5162, 'longitude': 14.5501},
    'Azerbaijan': {'latitude': 40.1431, 'longitude': 47.5769},
    'Bahamas': {'latitude': 25.0343, 'longitude': -77.3963},
    'Bahrain': {'latitude': 26.0667, 'longitude': 50.5577},
    'Bangladesh': {'latitude': 23.6850, 'longitude': 90.3563},
    'Barbados': {'latitude': 13.1939, 'longitude': -59.5432},
    'Belarus': {'latitude': 53.7098, 'longitude': 27.9534},
    'Belgium': {'latitude': 50.8503, 'longitude': 4.3517},
    'Belize': {'latitude': 17.1899, 'longitude': -88.4976},
    'Benin': {'latitude': 9.3077, 'longitude': 2.3158},
    'Bhutan': {'latitude': 27.5142, 'longitude': 90.4336},
    'Syria': {'latitude': 34.8021, 'longitude': 38.9968},
    'Taiwan*': {'latitude': 23.6978, 'longitude': 120.9605},
    'Tajikistan': {'latitude': 38.8610, 'longitude': 71.2761},
    'Tanzania': {'latitude': -6.369028, 'longitude': 34.888822},
    'Thailand': {'latitude': 15.8700, 'longitude': 100.9925},
    'Timor-Leste': {'latitude': -8.8742, 'longitude': 125.7275},
    'Togo': {'latitude': 8.6195, 'longitude': 0.8248},
    'Trinidad and Tobago': {'latitude': 10.6918, 'longitude': -61.2225},
    'Tunisia': {'latitude': 33.8869, 'longitude': 9.5375},
    'Turkey': {'latitude': 38.9637, 'longitude': 35.2433},
    'US': {'latitude': 37.0902, 'longitude': -95.7129},
    'Uganda': {'latitude': 1.3733, 'longitude': 32.2903},
    'Ukraine': {'latitude': 48.3794, 'longitude': 31.1656},
    'United Arab Emirates': {'latitude': 23.4241, 'longitude': 53.8478},
    'United Kingdom': {'latitude': 55.3781, 'longitude': -3.4360},
    'Uruguay': {'latitude': -32.5228, 'longitude': -55.7658},
    'Uzbekistan': {'latitude': 41.3775, 'longitude': 64.5853},
    'Venezuela': {'latitude': 6.4238, 'longitude': -66.5897},
    'Vietnam': {'latitude': 14.0583, 'longitude': 108.2772},
    'West Bank and Gaza': {'latitude': 31.9522, 'longitude': 35.2332},
    'Western Sahara': {'latitude': 24.2155, 'longitude': -12.8858},
    'Yemen': {'latitude': 15.5524, 'longitude': 48.5164},
    'Zambia': {'latitude': -13.1339, 'longitude': 27.8493},
    'Zimbabwe': {'latitude': -19.0154, 'longitude': 29.1549},
}

# %%
y = random.randrange(len(df)-1)


highlight_country = df.iloc[y]['Country/Region']

latitudes = pd.DataFrame.from_dict(coordinates, orient='index', columns=['latitude'])
longitudes = pd.DataFrame.from_dict(coordinates, orient='index', columns=['longitude'])

# Reorder data to have the highlighted country first
latitudes = latitudes.loc[[highlight_country] + [country for country in latitudes.index if country != highlight_country]]
longitudes = longitudes.loc[[highlight_country] + [country for country in longitudes.index if country != highlight_country]]


# Create a scatter plot with latitude and longitude as markers
fig = go.Figure()

df['hover_text'] = (
    '<br>Location: ' + df['Country/Region'] +
    '<br>Confirmed: ' + df['Confirmed'].astype(str) +
    '<br>Active : ' + df['Active'].astype(str) +
    '<br>Recovered : ' + df['Recovered'].astype(str) +
    '<br>Death : ' + df['Deaths'].astype(str)
)

# Add scatter plot with lat and long as markers
fig.add_trace(go.Scattergeo(
    lon=longitudes['longitude'],
    lat=latitudes['latitude'],
    mode='markers',
    marker=dict(
        size=8,  # Adjust the marker size as needed
        color=['red' if country == highlight_country else 'blue' for country in latitudes.index],
    ),
    text=df['hover_text'],  # Location text to display on hover
))



# Set an initial rotation angle
initial_rotation = dict(lon=longitudes.iloc[y]['longitude'], lat=latitudes.iloc[y]['latitude'])

# Update layout settings to set the initial rotation
fig.update_geos(projection_type='orthographic')
fig.update_geos(showland=True)
fig.update_layout(
    legend_title_text='Categories',
    geo=dict(
        projection_rotation=initial_rotation
    )
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y = random.randrange(len(df)-1)

data = {'Confirmed':df.iloc[y]['Confirmed'],
        'Active':df.iloc[y]['Active'],
        'Recovered':df.iloc[y]['Recovered'],
        'Death':df.iloc[y]['Deaths'],
        'LastWeek' : df.iloc[y]['Confirmed last week'],
        'Increased In Last Week' : df.iloc[y]['1 week change']}

courses = list(data.keys())
values = list(data.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=courses, y=values, marker_color='maroon')])

fig.update_layout(
    title=df.iloc[y]['Country/Region'],
    xaxis=dict(title='Cases'),
    yaxis=dict(title='No. of Cases'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y = random.randrange(len(df)-1)

Active_Ratio = []

for i in range(0, len(df)):
  Active_Ratio.append((df.iloc[i]['Active']/df.iloc[i]['Confirmed'])*100)

data = { 'Active Ratio':Active_Ratio[y],
        'Recovered Ratio':df.iloc[y]['Recovered / 100 Cases'],
        'Death Ratio':df.iloc[y]['Deaths / 100 Cases'],
        'Increased In Last Week Ratio' : df.iloc[y]['1 week % increase']}

courses = list(data.keys())
values = list(data.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=courses, y=values, marker_color='maroon')])

fig.update_layout(
    title=df.iloc[y]['Country/Region'],
    xaxis=dict(title='Cases'),
    yaxis=dict(title='No. of Cases'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Worldometer

# %%
df = pd.read_csv("/content/drive/MyDrive/Covid_19/worldometer_data.csv")

# %%
df
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
rowColumn = df.shape
print("No of Rows   : ",rowColumn[0])
print("No of Column : ",rowColumn[1])
print("Size         : ",df.size)
# Out:
# No of Rows   :  209
# No of Column :  16
# Size         :  3344

# %%
df.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
df.isnull()
# Out:
#      Country/Region  Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 0             False      False       False       False      True        False
# 1             False      False       False       False      True        False
# 2             False      False       False       False      True        False
# 3             False      False       False       False      True        False
# 4             False      False       False       False      True        False
# ..              ...        ...         ...         ...       ...          ...
# 204           False      False       False       False      True        False
# 205           False      False       False       False      True         True
# 206           False      False       False       False      True         True
# 207           False      False       False       False      True         True
# 208           False      False       False       False      True        False
#
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
df['TotalDeaths'] = df['TotalDeaths'].fillna(0)
df['TotalRecovered'] = df['TotalRecovered'].fillna(0)
df['ActiveCases'] = df['ActiveCases'].fillna(0)
df['Serious,Critical'] = df['Serious,Critical'].fillna(0)
df['Deaths/1M pop'] = df['Deaths/1M pop'].fillna(0)
df['TotalTests'] = df['TotalTests'].fillna(0)
df['Tests/1M pop'] = df['Tests/1M pop'].fillna(0)

df.drop('NewCases', inplace=True, axis=1)
df.drop('NewDeaths', inplace=True, axis=1)
df.drop('NewRecovered', inplace=True, axis=1)
df.drop(156, inplace=True, axis=0)

# %%
df = df.reset_index(drop = True)

# %%
unique_continent = df['Continent'].unique()
unique_continent
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania'], dtype=object)

# %%
continent_count = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_count):
    continent_count[df.iloc[i]['Continent']] += 1
  else:
    continent_count[df.iloc[i]['Continent']] = 1

continent_count
# Out:
# {'North America': 35,
#  'South America': 14,
#  'Asia': 48,
#  'Europe': 48,
#  'Africa': 57,
#  'Australia/Oceania': 6}

# %%
continent_confirmed = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_confirmed ):
    continent_confirmed[df.iloc[i]['Continent']] += df.iloc[i]['TotalCases']
  else:
    continent_confirmed[df.iloc[i]['Continent']] = df.iloc[i]['TotalCases']

continent_confirmed
# Out:
# {'North America': 5919209,
#  'South America': 4543273,
#  'Asia': 4689794,
#  'Europe': 2982576,
#  'Africa': 1011867,
#  'Australia/Oceania': 21735}

# %%
continent_recovered = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_recovered):
    continent_recovered[df.iloc[i]['Continent']] += df.iloc[i]['TotalRecovered']
  else:
    continent_recovered[df.iloc[i]['Continent']] = df.iloc[i]['TotalRecovered']

continent_recovered
# Out:
# {'North America': 3151678.0,
#  'South America': 3116150.0,
#  'Asia': 3508170.0,
#  'Europe': 1587302.0,
#  'Africa': 693620.0,
#  'Australia/Oceania': 12620.0}

# %%
continent_death = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_death):
    continent_death[df.iloc[i]['Continent']] += df.iloc[i]['TotalDeaths']
  else:
    continent_death[df.iloc[i]['Continent']] = df.iloc[i]['TotalDeaths']

continent_death
# Out:
# {'North America': 229855.0,
#  'South America': 154885.0,
#  'Asia': 100627.0,
#  'Europe': 205232.0,
#  'Africa': 22114.0,
#  'Australia/Oceania': 281.0}

# %%
continent_active = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_active):
    continent_active[df.iloc[i]['Continent']] += df.iloc[i]['ActiveCases']
  else:
    continent_active[df.iloc[i]['Continent']] = df.iloc[i]['ActiveCases']

continent_active
# Out:
# {'North America': 2537676.0,
#  'South America': 1272238.0,
#  'Asia': 1080997.0,
#  'Europe': 475261.0,
#  'Africa': 296133.0,
#  'Australia/Oceania': 8834.0}

# %%
continent_serious = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_serious):
    continent_serious[df.iloc[i]['Continent']] += df.iloc[i]['Serious,Critical']
  else:
    continent_serious[df.iloc[i]['Continent']] = df.iloc[i]['Serious,Critical']

continent_serious
# Out:
# {'North America': 25709.0,
#  'South America': 14295.0,
#  'Asia': 18749.0,
#  'Europe': 5200.0,
#  'Africa': 1187.0,
#  'Australia/Oceania': 52.0}

# %%
continent_test = {}

for i in range(len(df)):
  if(df.iloc[i]['Continent'] in continent_test):
    continent_test[df.iloc[i]['Continent']] += df.iloc[i]['TotalTests']
  else:
    continent_test[df.iloc[i]['Continent']] = df.iloc[i]['TotalTests']

continent_test
# Out:
# {'North America': 70173584.0,
#  'South America': 22379618.0,
#  'Asia': 65353821.0,
#  'Europe': 96125611.0,
#  'Africa': 8673853.0,
#  'Australia/Oceania': 5152811.0}

# %%
NorthAmerica = df[df['Continent'] == 'North America']
SouthAmerica = df[df['Continent'] == 'South America']
Asia = df[df['Continent'] == 'Asia']
Europe = df[df['Continent'] == 'Europe']
Africa = df[df['Continent'] == 'Africa']
Australia = df[df['Continent'] == 'Australia/Oceania']

# %%
NorthAmerica = NorthAmerica.reset_index(drop=True)
SouthAmerica = SouthAmerica.reset_index(drop=True)
Asia = Asia.reset_index(drop=True)
Europe = Europe.reset_index(drop=True)
Africa = Africa.reset_index(drop=True)
Australia = Australia.reset_index(drop=True)

# %%
print(NorthAmerica.nlargest(5, ['TotalCases']))
print(NorthAmerica.nlargest(5, ['TotalDeaths']))
print(NorthAmerica.nlargest(5, ['TotalRecovered']))
print(NorthAmerica.nlargest(5, ['ActiveCases']))
print(NorthAmerica.nlargest(5, ['Serious,Critical']))
print(NorthAmerica.nlargest(5, ['TotalTests']))

# %%
print(SouthAmerica.nlargest(5, ['TotalCases']))
print(SouthAmerica.nlargest(5, ['TotalDeaths']))
print(SouthAmerica.nlargest(5, ['TotalRecovered']))
print(SouthAmerica.nlargest(5, ['ActiveCases']))
print(SouthAmerica.nlargest(5, ['Serious,Critical']))
print(SouthAmerica.nlargest(5, ['TotalTests']))

# %%
print(Asia.nlargest(5, ['TotalCases']))
print(Asia.nlargest(5, ['TotalDeaths']))
print(Asia.nlargest(5, ['TotalRecovered']))
print(Asia.nlargest(5, ['ActiveCases']))
print(Asia.nlargest(5, ['Serious,Critical']))
print(Asia.nlargest(5, ['TotalTests']))

# %%
print(Europe.nlargest(5, ['TotalCases']))
print(Europe.nlargest(5, ['TotalDeaths']))
print(Europe.nlargest(5, ['TotalRecovered']))
print(Europe.nlargest(5, ['ActiveCases']))
print(Europe.nlargest(5, ['Serious,Critical']))
print(Europe.nlargest(5, ['TotalTests']))

# %%
print(Africa.nlargest(5, ['TotalCases']))
print(Africa.nlargest(5, ['TotalDeaths']))
print(Africa.nlargest(5, ['TotalRecovered']))
print(Africa.nlargest(5, ['ActiveCases']))
print(Africa.nlargest(5, ['Serious,Critical']))
print(Africa.nlargest(5, ['TotalTests']))

# %%
print(Australia.nlargest(5, ['TotalCases']))
print(Australia.nlargest(5, ['TotalDeaths']))
print(Australia.nlargest(5, ['TotalRecovered']))
print(Australia.nlargest(5, ['ActiveCases']))
print(Australia.nlargest(5, ['Serious,Critical']))
print(Australia.nlargest(5, ['TotalTests']))

# %%
print("Total Population of NorthAmerica: ", int(NorthAmerica['Population'].sum()))
print("Total Cases in NorthAmerica     : ",NorthAmerica['TotalCases'].sum())
print(round((NorthAmerica['TotalCases'].sum()/NorthAmerica['Population'].sum())*100, 2))
# Out:
# Total Population of NorthAmerica:  589503467
# Total Cases in NorthAmerica     :  5919209
# 1.0

# %%
print("Total Population of SouthAmerica: ", int(SouthAmerica['Population'].sum()))
print("Total Cases in SouthAmerica     : ",SouthAmerica['TotalCases'].sum())
print(round((SouthAmerica['TotalCases'].sum()/SouthAmerica['Population'].sum())*100, 2))
# Out:
# Total Population of SouthAmerica:  431110464
# Total Cases in SouthAmerica     :  4543273
# 1.05

# %%
print("Total Population of Asia: ", int(Asia['Population'].sum()))
print("Total Cases in Asia     : ",Asia['TotalCases'].sum())
print(round((Asia['TotalCases'].sum()/Asia['Population'].sum())*100, 2))
# Out:
# Total Population of Asia:  3173656415
# Total Cases in Asia     :  4689794
# 0.15

# %%
print("Total Population of Europe: ", int(Europe['Population'].sum()))
print("Total Cases in Europe     : ",Europe['TotalCases'].sum())
print(round((Europe['TotalCases'].sum()/Europe['Population'].sum())*100, 2))
# Out:
# Total Population of Europe:  747677546
# Total Cases in Europe     :  2982576
# 0.4

# %%
print("Total Population of Africa: ", int(Africa['Population'].sum()))
print("Total Cases in Africa     : ",Africa['TotalCases'].sum())
print(round((Africa['TotalCases'].sum()/Africa['Population'].sum())*100, 2))
# Out:
# Total Population of Africa:  1343515489
# Total Cases in Africa     :  1011867
# 0.08

# %%
print("Total Population of Australia: ", int(Australia['Population'].sum()))
print("Total Cases in Australia     : ",Australia['TotalCases'].sum())
print(round((Australia['TotalCases'].sum()/Australia['Population'].sum())*100, 2))
# Out:
# Total Population of Australia:  40957909
# Total Cases in Australia     :  21735
# 0.05

# %%
continent = list(continent_count.keys())
count = list(continent_count.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'Continent VS Country',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Country Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_confirmed.keys())
count = list(continent_confirmed.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Confirmed Cases in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_confirmed.keys()),
    values=list(continent_confirmed.values()),
    title='Distribution of Confirmed Cases by Continent',
    labels={'names': 'Continent', 'values': 'Confirmed Cases'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_recovered.keys())
count = list(continent_recovered.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Recovered Cases in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_recovered.keys()),
    values=list(continent_recovered.values()),
    title='Distribution of Recovered Cases by Continent',
    labels={'names': 'Continent', 'values': 'Recovered Cases'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_death.keys())
count = list(continent_death.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Death Cases in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_death.keys()),
    values=list(continent_death.values()),
    title='Distribution of Death Cases by Continent',
    labels={'names': 'Continent', 'values': 'Death Cases'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_active.keys())
count = list(continent_active.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Active Cases in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_active.keys()),
    values=list(continent_active.values()),
    title='Distribution of Active Cases by Continent',
    labels={'names': 'Continent', 'values': 'Active Cases'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_serious.keys())
count = list(continent_serious.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Critical Cases in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Country Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_serious.keys()),
    values=list(continent_serious.values()),
    title='Distribution of Critical Cases by Continent',
    labels={'names': 'Continent', 'values': 'Critical Cases'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
continent = list(continent_test.keys())
count = list(continent_test.values())

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(x=continent, y=count, marker_color='maroon')])

fig.update_layout(
    title= 'No of Test in each Continent',
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Count'),
    width=1000,
    height=400
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(
    names=list(continent_test.keys()),
    values=list(continent_test.values()),
    title='Distribution of Test by Continent',
    labels={'names': 'Continent', 'values': 'Test'}
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
